# %% [markdown]
# # Machine Learning for Absolute Beginners

# %% [markdown]
# # Load Libraries

# %%
# load libraries
import pandas as pd

# %% [markdown]
# # 0. Create DataFrame

# %%
url = "https://tinyurl.com/titanic-data-csv"

# %%
df = pd.read_csv(url)

# %% [markdown]
# # 1. Describe Data

# %%
# show first five rows

# %%
# dataframe info

# %%
# dataframe statistics

# %%
# show dataframe shape

# %%
# show dataframe size

# %%
# show counts of missing values

# %%
# visualize missing values

# %% [markdown]
# # 1. Select and Filter Data

# %%
# select rows based on index iloc

# %%
# select rows based on index

# %%
# selecting one row returns a series object

# %%
# select single column

# %%
# alternately use dot notation (discouraged)
# df.Name

# %%
# select multiple columns by specifying a list

# %%
# select columns based on column labels with .loc

# %%
# select range of columns

# %%
# select rows and columns with list for columns

# %%
# Select Rows Based on conditionals

# %%
# multiple conditions

# %%
# chain commands

# %%
# What was the mean age of everyone who embarked in Southampton?
# What was the mean fare of all men who embarked in Cherbourg? and or ...

# %% [markdown]
# # Grouping Rows by Values

# %%
# group by sex

# %%
# summarize by mean

# %%
# summarize by count

# %%
# what are the counts for those who embarked by port
# and survival counts

# %%
# group by embarked

# %%
# counts

# %%
# mean

# %%
# value counts of survivors

# %%
# value counts of survivors normalized

# %%
# multiple groupby Embarked, Sex; mean fare

# %%
# multiple groupby Pclass, Sex; Count

# %%
# multiple groupby Pclass, Sex; mean fare
